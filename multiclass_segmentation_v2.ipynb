# %% [markdown]
# <a href="https://colab.research.google.com/github/poliduckie/MPC/blob/main/multiclass_segmentation_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# now we can see Drive as local
# Out:
# Mounted at /content/gdrive

# %%
import os
from PIL import Image
from numpy import asarray
import numpy as np
import keras
from keras import layers
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2 as cv2
import sys

# %%
# load every image into memory
ORIG = '/content/gdrive/MyDrive/images_stable/rgb_orig_rand'
TARGET = '/content/gdrive/MyDrive/images_stable/rgb_ss'

n = 6 # 100
TRAIN_DIM = 3 # 60
x_train = []
y_train = []

for i in range(n):
  if os.path.isfile(os.path.join(ORIG, f'{i}.png')):
    img = Image.open(os.path.join(ORIG, f'{i}.png'))
    data = asarray(img)
    x_train.append(data)
    img = Image.open(os.path.join(TARGET, f'{i}_seg.png'))
    data = asarray(img)
    y_train.append(data)

drive.flush_and_unmount()

# %%
# !git clone https://github.com/poliduckie/MPC.git
# %cd MPC
# !ls
# Out:
# Cloning into 'MPC'...
# remote: Enumerating objects: 3189, done.
# remote: Counting objects: 100% (3189/3189), done.
# remote: Compressing objects: 100% (1431/1431), done.
# remote: Total 3189 (delta 1751), reused 3111 (delta 1727), pack-reused 0
# Receiving objects: 100% (3189/3189), 59.54 MiB | 13.06 MiB/s, done.
# Resolving deltas: 100% (1751/1751), done.
# /content/MPC/MPC
# dataset_generation	      OpenCV		     UNet_full_res_model
# gym-duckietown		      README.md		     U_net_model.ipynb
# LaneDetection_test.ipynb      ReinforcementLearning
# One_LaneDetection_test.ipynb  UNet_full_res.ipynb

# %%
x_train = [np.delete(elem, [False, False, False, True], axis=2) for elem in x_train]
y_train = [np.delete(elem, [False, False, False, True], axis=2) for elem in y_train]
print(len(x_train))
# Out:
# 4

# %%
x_test = x_train[TRAIN_DIM:]
x_train = x_train[:TRAIN_DIM]
y_test = y_train[TRAIN_DIM:]
y_train = y_train[:TRAIN_DIM]

#print(x_train[0])
x_train = np.array(x_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
y_train = np.array(y_train)

# %%
def separate_classes(img):
  img = np.copy(img)
  # remove magenta
  img[np.all(img == np.array([255,0,254]), axis=-1)] = np.array([0,0,0])
  img_white = np.copy(img)
  img_yellow = np.copy(img)
  img_no_line = np.copy(img)
  # white line
  img_white[np.all(img_white == np.array([255,255,0]), axis=-1)] = np.array([0,0,0])
  img_white = resize(img_white, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range='true' )
  img_white=img_white[:,:,:1]
  img_white = np.squeeze(img_white)
  img_white = img_white/255.

  # yellow line
  img_yellow[np.all(img_yellow == np.array([255,255,255]), axis=-1)] = np.array([0,0,0])
  img_yellow[np.all(img_yellow == np.array([255,255,0]), axis=-1)] = np.array([255,255,255])
  img_yellow = resize(img_yellow, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range='true' )
  img_yellow=img_yellow[:,:,:1]
  img_yellow = np.squeeze(img_yellow)
  img_yellow = img_yellow/255.

  # not a line
  img_no_line[np.all(img_no_line == np.array([255,255,255]), axis=-1)] = np.array([255,255,0])
  img_no_line[np.all(img_no_line == np.array([0,0,0]), axis=-1)] = np.array([255,255,255])
  img_no_line[np.all(img_no_line == np.array([255,255,0]), axis=-1)] = np.array([0,0,0])
  img_no_line = resize(img_no_line, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range='true' )
  img_no_line=img_no_line[:,:,:1]
  img_no_line = np.squeeze(img_no_line)
  img_no_line = img_no_line/255.

  img_masks = np.array([img_white,img_yellow,img_no_line])
  return img_masks

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 240
IMG_CHANNELS = 3
N_CLASSES = 3  #  central line (yellow), lateral line (white) and not a line

LENGTH = y_train.shape[0]

Y_train = []

for i in range(LENGTH):
  img = np.copy(y_train[i])
  img = separate_classes(img)
  Y_train.append(img)
  
y_train = np.array(Y_train)
print(y_train.shape)
#y_train = np.swapaxes(np.swapaxes(y_train, 1, 2), 2, 3)
y_train = np.moveaxis(y_train, 1, -1)
print(y_train[0].shape)
# Out:
# (3, 3, 240, 320)
# (240, 320, 3)

# %%
LENGTH = y_test.shape[0]

Y_test = []

for i in range(LENGTH):
  img = np.copy(y_test[i])
  img = separate_classes(img)
  Y_test.append(img)
  
y_test = np.array(Y_test)
#y_test = np.swapaxes(np.swapaxes(y_test, 1, 2), 2, 3)
y_test = np.moveaxis(y_test, 1, -1)
print(y_test[0].shape)
# Out:
# (240, 320, 3)

# %%
BATCH_SIZE = 1

# %% [markdown]
# If the model isn't sufficiently accurate we can try to enlarge conv2D layers' outputs

# %%
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x:x /255)(inputs)

# %%
c1 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)

# %%
c2 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)

# %%
c3 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)

# %%
c4 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.1)(c4)
c4 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)

# %%
c5 = tf.keras.layers.Conv2D(256, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(256, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c5)

# %%
u6 = tf.keras.layers.Convolution2DTranspose(128, (2,2), strides=(2,2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4]) #merge with old layer
c6 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.1)(c6)
c6 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c6)

# %%
u7 = tf.keras.layers.Convolution2DTranspose(64, (2,2), strides=(2,2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])  #merge with old layer
c7 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.1)(c7)
c7 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c7)

# %%
u8 = tf.keras.layers.Convolution2DTranspose(32, (2,2), strides=(2,2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])  #merge with old layer
c8 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c8)

# %%
u9 = tf.keras.layers.Convolution2DTranspose(16, (2,2), strides=(2,2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1])  #merge with old layer
c9 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer='he_normal', padding='same')(c9)

# %%
outputs = tf.keras.layers.Conv2D(N_CLASSES, (1,1), activation = 'softmax')(c9)

# %%
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()

checkpointer = tf.keras.callbacks.ModelCheckpoint('duckie_street.h5', verbose=1, save_best_only=True)
callbacks=[
    tf.keras.callbacks.EarlyStopping(patience=100, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir='logs')]
results = model.fit(x_train,y_train, validation_split=0.1, batch_size = BATCH_SIZE, epochs=100, callbacks=callbacks)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 240, 320, 3  0           []
#                                 )]
#
#  lambda_1 (Lambda)              (None, 240, 320, 3)  0           ['input_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 240, 320, 16  448         ['lambda_1[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 240, 320, 16  0           ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 240, 320, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 120, 160, 16  0          ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 120, 160, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 120, 160, 32  0           ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 120, 160, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 60, 80, 32)  0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 60, 80, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  dropout_11 (Dropout)           (None, 60, 80, 64)   0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 60, 80, 64)   36928       ['dropout_11[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 30, 40, 64)  0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 30, 40, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  dropout_12 (Dropout)           (None, 30, 40, 128)  0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 30, 40, 128)  147584      ['dropout_12[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 15, 20, 128)  0          ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 15, 20, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  dropout_13 (Dropout)           (None, 15, 20, 256)  0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 15, 20, 256)  590080      ['dropout_13[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 30, 40, 128)  131200     ['conv2d_28[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 30, 40, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 30, 40, 128)  295040      ['concatenate_4[0][0]']
#
#  dropout_14 (Dropout)           (None, 30, 40, 128)  0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 30, 40, 128)  147584      ['dropout_14[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 60, 80, 64)  32832       ['conv2d_30[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 60, 80, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 60, 80, 64)   73792       ['concatenate_5[0][0]']
#
#  dropout_15 (Dropout)           (None, 60, 80, 64)   0           ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 60, 80, 64)   36928       ['dropout_15[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 120, 160, 32  8224       ['conv2d_32[0][0]']
#  spose)                         )
#
#  concatenate_6 (Concatenate)    (None, 120, 160, 64  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 120, 160, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 120, 160, 32  0           ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 120, 160, 32  9248        ['dropout_16[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 240, 320, 16  2064       ['conv2d_34[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 240, 320, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 240, 320, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  dropout_17 (Dropout)           (None, 240, 320, 16  0           ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 240, 320, 16  2320        ['dropout_17[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 240, 320, 3)  51          ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1,941,139
# Trainable params: 1,941,139
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.7281 - val_loss: 0.6390
# Epoch 2/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6243 - val_loss: 0.5089
# Epoch 3/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4657 - val_loss: 0.3023
# Epoch 4/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.3090 - val_loss: 0.1765
# Epoch 5/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2592 - val_loss: 0.1820
# Epoch 6/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2296 - val_loss: 0.1872
# Epoch 7/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2110 - val_loss: 0.1223
# Epoch 8/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1978 - val_loss: 0.1944
# Epoch 9/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1869 - val_loss: 0.1242
# Epoch 10/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1736 - val_loss: 0.2364
# Epoch 11/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1638 - val_loss: 0.1334
# Epoch 12/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.1532 - val_loss: 0.2988
# Epoch 13/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1456 - val_loss: 0.2118
# Epoch 14/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1340 - val_loss: 0.2667
# Epoch 15/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1220 - val_loss: 0.2447
# Epoch 16/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1051 - val_loss: 0.2186
# Epoch 17/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1006 - val_loss: 0.2925
# Epoch 18/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0959 - val_loss: 0.2302
# Epoch 19/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0919 - val_loss: 0.2089
# Epoch 20/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0837 - val_loss: 0.2722
# Epoch 21/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0825 - val_loss: 0.2687
# Epoch 22/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0774 - val_loss: 0.1855
# Epoch 23/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0750 - val_loss: 0.2265
# Epoch 24/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0712 - val_loss: 0.2404
# Epoch 25/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0703 - val_loss: 0.2145
# Epoch 26/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0686 - val_loss: 0.1661
# Epoch 27/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0659 - val_loss: 0.2018
# Epoch 28/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0646 - val_loss: 0.2482
# Epoch 29/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0635 - val_loss: 0.2036
# Epoch 30/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0617 - val_loss: 0.1919
# Epoch 31/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0626 - val_loss: 0.2640
# Epoch 32/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0614 - val_loss: 0.2897
# Epoch 33/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0608 - val_loss: 0.2938
# Epoch 34/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0598 - val_loss: 0.2992
# Epoch 35/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0582 - val_loss: 0.2641
# Epoch 36/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0576 - val_loss: 0.2793
# Epoch 37/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0577 - val_loss: 0.2857
# Epoch 38/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0569 - val_loss: 0.2728
# Epoch 39/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0566 - val_loss: 0.3161
# Epoch 40/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0558 - val_loss: 0.2852
# Epoch 41/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0543 - val_loss: 0.2456
# Epoch 42/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0542 - val_loss: 0.2673
# Epoch 43/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0537 - val_loss: 0.2820
# Epoch 44/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0528 - val_loss: 0.2465
# Epoch 45/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0525 - val_loss: 0.2680
# Epoch 46/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0515 - val_loss: 0.3050
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0510 - val_loss: 0.2787
# Epoch 48/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0509 - val_loss: 0.2999
# Epoch 49/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0500 - val_loss: 0.3195
# Epoch 50/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0496 - val_loss: 0.2558
# Epoch 51/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0492 - val_loss: 0.2761
# Epoch 52/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0485 - val_loss: 0.2978
# Epoch 53/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0471 - val_loss: 0.2726
# Epoch 54/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0466 - val_loss: 0.2960
# Epoch 55/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0455 - val_loss: 0.2946
# Epoch 56/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0443 - val_loss: 0.2745
# Epoch 57/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0441 - val_loss: 0.3066
# Epoch 58/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0424 - val_loss: 0.3044
# Epoch 59/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0414 - val_loss: 0.2917
# Epoch 60/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0403 - val_loss: 0.3177
# Epoch 61/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0386 - val_loss: 0.2917
# Epoch 62/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0369 - val_loss: 0.3126
# Epoch 63/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0357 - val_loss: 0.2751
# Epoch 64/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0343 - val_loss: 0.3641
# Epoch 65/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0334 - val_loss: 0.3079
# Epoch 66/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0330 - val_loss: 0.3305
# Epoch 67/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0309 - val_loss: 0.3142
# Epoch 68/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0328 - val_loss: 0.4586
# Epoch 69/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0340 - val_loss: 0.3282
# Epoch 70/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0314 - val_loss: 0.3715
# Epoch 71/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0318 - val_loss: 0.4172
# Epoch 72/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0300 - val_loss: 0.3056
# Epoch 73/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0305 - val_loss: 0.3985
# Epoch 74/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0269 - val_loss: 0.5016
# Epoch 75/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0273 - val_loss: 0.4599
# Epoch 76/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0249 - val_loss: 0.4222
# Epoch 77/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0240 - val_loss: 0.4298
# Epoch 78/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0233 - val_loss: 0.3948
# Epoch 79/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0225 - val_loss: 0.4010
# Epoch 80/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0217 - val_loss: 0.4162
# Epoch 81/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0210 - val_loss: 0.3868
# Epoch 82/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0202 - val_loss: 0.3858
# Epoch 83/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0195 - val_loss: 0.3962
# Epoch 84/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0190 - val_loss: 0.4110
# Epoch 85/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0181 - val_loss: 0.4217
# Epoch 86/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0183 - val_loss: 0.4079
# Epoch 87/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0175 - val_loss: 0.4126
# Epoch 88/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0166 - val_loss: 0.4137
# Epoch 89/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0167 - val_loss: 0.3777
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0161 - val_loss: 0.4419
# Epoch 91/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0153 - val_loss: 0.4515
# Epoch 92/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0149 - val_loss: 0.4522
# Epoch 93/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0147 - val_loss: 0.4188
# Epoch 94/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0140 - val_loss: 0.4270
# Epoch 95/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0140 - val_loss: 0.4422
# Epoch 96/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0136 - val_loss: 0.5230
# Epoch 97/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0134 - val_loss: 0.5119
# Epoch 98/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0132 - val_loss: 0.4529
# Epoch 99/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0129 - val_loss: 0.3915
# Epoch 100/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0128 - val_loss: 0.5762

# %%
import random
import matplotlib.pyplot

seed = 42
np.random.seed = seed

# %%
# %matplotlib inline
TEST_LENGTH = x_test.shape[0]
print(TEST_LENGTH)
idx1 = np.random.randint(0,TEST_LENGTH)
idx2 = np.random.randint(0,TEST_LENGTH)

# 1
imshow(x_test[idx1])
plt.show()

prediction = model.predict(x_test[idx1].reshape((1,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
prediction = np.squeeze(prediction)

masks = []
max_vals = prediction.max(axis=-1) #take the max value along the probability axis
for i in range(N_CLASSES):
  masks.append(prediction[:,:,i] == max_vals)
  masks[i] = np.array(masks[i], dtype=int)
  masks[i] = np.array([masks[i]*255 for _ in range(3)])
  masks[i] = np.moveaxis(masks[i], 0, -1)
  imshow(masks[i])
  plt.show()



# 2
imshow(x_test[idx2])
plt.show()

prediction = model.predict(x_test[idx2].reshape((1,IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
prediction = np.squeeze(prediction)

masks = []
max_vals = prediction.max(axis=-1) #take the max value along the probability axis
for i in range(N_CLASSES):
  masks.append(prediction[:,:,i] == max_vals)
  masks[i] = np.array(masks[i], dtype=int)
  masks[i] = np.array([masks[i]*255 for _ in range(3)])
  masks[i] = np.moveaxis(masks[i], 0, -1)
  imshow(masks[i])
  plt.show()
# Out:
# 1
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 229ms/step
